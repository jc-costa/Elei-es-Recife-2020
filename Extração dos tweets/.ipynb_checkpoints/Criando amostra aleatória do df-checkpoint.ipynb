# %% [markdown]
# ### Gerando amostra aleatoria de dados

# %%
import pandas as pd

# %%
pd.set_option('display.max_colwidth', 250)

# %%
df = pd.read_csv('./dataset_treino', index_col=[0])

# %%
df
# Out:
#       palavra_chave  \
# 0    Marília Arraes
# 1    Marília Arraes
# 2    Marília Arraes
# 3    Marília Arraes
# 4    Marília Arraes
# ..              ...
# 195  Mendonça Filho
# 196  Mendonça Filho
# 197  Mendonça Filho
# 198  Mendonça Filho
# 199  Mendonça Filho
#
#                                                                                                                                                                                                                                                          tweet
# 0                                                                                                                                                               Marilia Arraes quer linha de credito sem juros para retomada economica https://t.co/MpILCKs3Cy
# 1                                                          @EstimaWalmir @travestiviva @santuzza_souza Na verdade eu, homem cis gay, to confrontando um homem cis privilegiado querendo silenciar pessoas da comunidade T em nome da candidata Marilia Arraes.
# 2                                                                                                                                                                 E impressao minha ou a voz do jingle de Marilia Arraes e de Flavio Leandro???  #Eleicoes2020
# 3                                                                                                                RT @travestiviva: A candidata pelo PT a Prefeitura do Recife, Marilia Arraes, divulgou um video de campanha ao lado de uma famosa ativista...
# 4                                                                                                               RT @blogdejamildo: Marilia Arraes promete pacto para protecao a criancas e adolescentes no Recife https://t.co/lnlvCXh2M0 https://t.co/5n1W...
# ..                                                                                                                                                                                                                                                         ...
# 195                                                                                                                                                               sim mamae quero fazer audiovisual um dia meu nome vai ta ao lado do de kleber mendonca filho
# 196                                                                                                                                                        Opiniao Pernambuco - "Eleicoes 2020 - Mendonca Filho (DEM)" (03/11/2020)\r\nhttps://t.co/RsZYLPqxqR
# 197                                                                                      RT @Joaovaladares: Ibope no Recife:\r\nJoao Campos (PSB) -\r\n31% (-2)\r\n\r\nMarilia Arraes (PT) - \r\n18% (+4)\r\n\r\nDelegada Patricia (Podemos) - \r\n16% (+3)...
# 198  Pra ser honesto voce precisa ter um QI muito alto pra entender Kleber Mendonca filho. Repare como ele usa essa nuance do debate publico que e o brasileiro que nao se ve como latino apenas como um subterfugio para dar essa chinelada, sandaliada se...
# 199                                                                                                                                                                                                              @mvnnsk Alerta  \r\n\r\nKleber Mendonca Filho
#
# [200 rows x 2 columns]

# %%
dfSamples = df.sample(200)

# %%
dfSamples
# Out:
#          palavra_chave  \
# 153     Mendonça Filho
# 134  Delegada Patrícia
# 161     Mendonça Filho
# 114  Delegada Patrícia
# 150     Mendonça Filho
# ..                 ...
# 193     Mendonça Filho
# 35      Marília Arraes
# 103  Delegada Patrícia
# 9       Marília Arraes
# 33      Marília Arraes
#
#                                                                                                                                                                    tweet
# 153       Kleber Mendonca Filho\r\n@/kmendoncafilho\r\n\r\nO Bolsoniro e muito ruim, meu. O filme favorito dele deve ser A procura da Felicidade haha ! \r\n\r\n345 1348
# 134                       RT @revistaforum: Caso Delegada Patricia mostra necessidade de quarentena para policiais, juizes e promotores ja - por @ocolunista_  https:...
# 161                       RT @alicecristiny: Minha primeira colaboracao para a @agencialupa, checagem sobre o que Mendonca Filho esta dizendo e publicando na campanh...
# 114                                                                  RT @fellipecmaia: Nessa disputa americana por delegados Trump podia levar delegada Patricia pra ele
# 150  RT @xikino: "ABISMO TROPICAL" - dir: Paulo Caldas\r\nlive + exibicao\r\nonline e gratuito\r\n5/11, as 20h\r\nhttps://t.co/mwzZT6DzoW\r\n\r\nPaulo Caldas\r\nKleb...
# ..                                                                                                                                                                   ...
# 193                                                                                           Uma boa explicacao do genio Kleber Mendonca Filho. https://t.co/ScqLTRT7BF
# 35                                        Marilia Arraes promete pacto para protecao a criancas e adolescentes no Recife https://t.co/0SAcLzZO5R https://t.co/uTuGPUzz8r
# 103                                                             @gatinhapdtista @lhfcintra oxe o meu tinha Carlos tbm, Delegada Patricia, Mendonca tbm kkkkkkk nd com nd
# 9                                                                                                                Prefeita vota em Marilia Arraes https://t.co/7gnzzyNL14
# 33                         RT @travestiviva: A candidata pelo PT a Prefeitura do Recife, Marilia Arraes, divulgou um video de campanha ao lado de uma famosa ativista...
#
# [200 rows x 2 columns]

# %%
#Divindo o data frame em duas partes
a = dfSamples.sample(frac=0.5,random_state=1000)
b= dfSamples.drop(a.index)
c = a.sample(frac=0.5,random_state=1000)
d = a.drop(c.index)

# %%
dfSamples.to_csv('./tweets_treino')
a.to_csv('./adriano')
b.to_csv('./jefferson')
c.to_csv('./bruno')
d.to_csv('./matheus')
