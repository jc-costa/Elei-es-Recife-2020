# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
dfAdriano = pd.read_csv('./adriano')

# %%
analiseAdriano = [
    'Negativo',
    'Neutro',
    'Neutro',
    'Neutro',
    'Negativo',
    'Neutro',
    'Neutro',
    'Neutro',
    'Negativo',
    'Neutro',
    'Neutro',
    'Negativo',
    'Neutro',
    'Neutro',
    'Neutro',
    'Neutro',
    'Negativo',
    'Negativo',
    'Negativo',
    'Positivo',
    'Neutro',
    'Positivo',
    'Positivo',
    'Negativo',
    'Neutro',
    'Neutro',
    'Neutro',
    'Neutro',
    'Neutro',
    'Negativo',
    'Neutro',
    'Negativo',
    'Negativo',
    'Negativo',
    'Neutro',
    'Neutro',
    'Neutro',
    'Positivo',
    'Negativo',
    'Positivo',
    'Neutro',
    'Negativo',
    'Negativo',
    'Neutro',
    'Negativo',
    'Negativo',
    'Neutro',
    'Negativo',
    'Neutro',
    'Neutro',
    'Negativo',
    'Negativo',
    'Negativo',
    'Positivo',
    'Negativo',
    'Neutro',
    'Neutro',
    'Negativo',
    'Neutro',
    'Negativo',
    'Neutro',
    'Neutro',
    'Negativo',
    'Negativo',
    'Negativo',
    'Negativo',
    'Negativo',
    'Negativo',
    'Positivo',
    'Neutro',
    'Positivo',
    'Negativo'
    'Neutro',
    'Negativo',
    'Positivo',
    'Neutro',
    'Negativo',
    'Positivo',
    'Negativo',
    'Positivo',
    'Neutro',
    'Negativo',
    'Neutro',
    'Negativo',
    'Negativo',
    'Neutro',
    'Neutro',
    'Negativo',
    'Positivo',
    'Neutro',
    'Positivo',
    'Neutro',
    'Neutro',
    'Positivo',
    'Neutro',
    'Positivo',
    'Negativo',
    'Negativo',
    'Positivo',
    'Neutro'
]

# %%
dfAdriano
# Out:
#     Unnamed: 0      palavra_chave  \
# 0           23     Marília Arraes
# 1          135  Delegada Patrícia
# 2          105  Delegada Patrícia
# 3           24     Marília Arraes
# 4          167     Mendonça Filho
# ..         ...                ...
# 95         179     Mendonça Filho
# 96          75        João Campos
# 97         116  Delegada Patrícia
# 98          20     Marília Arraes
# 99         159     Mendonça Filho
#
#                                                 tweet
# 0   @deivanusa Entao quer dizer que se Marilia Arr...
# 1   RT @revistaforum: Caso Delegada Patricia mostr...
# 2   Delegada Patricia postou um video de depoiment...
# 3   RT @ReginaldoLopes: @MariliaArraes Viva o dout...
# 4   Nas hostes oposicionistas, alguns recados circ...
# ..                                                ...
# 95  Mendonca Filho Um marco na politica .Veja sou ...
# 96  RT @Ricardogama100: Cacete, ainda perguntam po...
# 97                      @jc_pe Delegada Patricia e uo
# ...
