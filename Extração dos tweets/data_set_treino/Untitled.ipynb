# %%
import pandas as pd

# %%
pd.set_option('display.max_columns', None)

# %%
dfAdriano.loc[99]
# Out:
# Unnamed: 0                                                 159
# palavra_chave                                   Mendonça Filho
# tweet            Kleber Mendonca Filho https://t.co/GHYp75SU5z
# Name: 99, dtype: object

# %%
dfAdriano = pd.read_csv('./adriano')

# %%
analiseAdriano = [
    'Negativo',
    'Neutro',
    'Neutro',
    'Neutro',
    'Negativo',
    'Neutro',
    'Neutro',
    'Neutro',
    'Negativo',
    'Neutro',
    'Neutro',
    'Negativo',
    'Neutro',
    'Neutro',
    'Neutro',
    'Neutro',
    'Negativo',
    'Negativo',
    'Negativo',
    'Positivo',
    'Neutro',
    'Positivo',
    'Positivo',
    'Negativo',
    'Neutro',
    'Neutro',
    'Neutro',
    'Neutro',
    'Neutro',
    'Negativo',
    'Neutro',
    'Negativo',
    'Negativo',
    'Negativo',
    'Neutro',
    'Neutro',
    'Neutro',
    'Positivo',
    'Negativo',
    'Positivo',
    'Neutro',
    'Negativo',
    'Negativo',
    'Neutro',
    'Negativo',
    'Negativo',
    'Neutro',
    'Negativo',
    'Neutro',
    'Neutro',
    'Negativo',
    'Negativo',
    'Negativo',
    'Positivo',
    'Negativo',
    'Neutro',
    'Neutro',
    'Negativo',
    'Neutro',
    'Negativo',
    'Neutro',
    'Neutro',
    'Negativo',
    'Negativo',
    'Negativo',
    'Negativo',
    'Negativo',
    'Negativo',
    'Positivo',
    'Neutro',
    'Positivo',
    'Negativo'
    'Neutro',
    'Negativo',
    'Positivo',
    'Neutro',
    'Negativo',
    'Positivo',
    'Negativo',
    'Positivo',
    'Neutro',
    'Negativo',
    'Neutro',
    'Negativo',
    'Negativo',
    'Neutro',
    'Neutro',
    'Negativo',
    'Positivo',
    'Neutro',
    'Positivo',
    'Neutro',
    'Neutro',
    'Positivo',
    'Neutro',
    'Positivo',
    'Negativo',
    'Negativo',
    'Positivo',
    'Neutro',
    'Neutro'
]

# %%
len(analiseAdriano)
# Out:
# 100

# %%
dfAdriano
# Out:
#     Unnamed: 0      palavra_chave  \
# 0           23     Marília Arraes
# 1          135  Delegada Patrícia
# 2          105  Delegada Patrícia
# 3           24     Marília Arraes
# 4          167     Mendonça Filho
# ..         ...                ...
# 95         179     Mendonça Filho
# 96          75        João Campos
# 97         116  Delegada Patrícia
# 98          20     Marília Arraes
# 99         159     Mendonça Filho
#
#                                                 tweet
# 0   @deivanusa Entao quer dizer que se Marilia Arr...
# 1   RT @revistaforum: Caso Delegada Patricia mostr...
# 2   Delegada Patricia postou um video de depoiment...
# 3   RT @ReginaldoLopes: @MariliaArraes Viva o dout...
# 4   Nas hostes oposicionistas, alguns recados circ...
# ..                                                ...
# 95  Mendonca Filho Um marco na politica .Veja sou ...
# 96  RT @Ricardogama100: Cacete, ainda perguntam po...
# 97                      @jc_pe Delegada Patricia e uo
# ...

# %%
dfAdriano['Analise'] = analiseAdriano

# %%
dfAdriano
# Out:
#     Unnamed: 0      palavra_chave  \
# 0           23     Marília Arraes
# 1          135  Delegada Patrícia
# 2          105  Delegada Patrícia
# 3           24     Marília Arraes
# 4          167     Mendonça Filho
# ..         ...                ...
# 95         179     Mendonça Filho
# 96          75        João Campos
# 97         116  Delegada Patrícia
# 98          20     Marília Arraes
# 99         159     Mendonça Filho
#
#                                                 tweet   Analise
# 0   @deivanusa Entao quer dizer que se Marilia Arr...  Negativo
# 1   RT @revistaforum: Caso Delegada Patricia mostr...    Neutro
# 2   Delegada Patricia postou um video de depoiment...    Neutro
# 3   RT @ReginaldoLopes: @MariliaArraes Viva o dout...    Neutro
# 4   Nas hostes oposicionistas, alguns recados circ...  Negativo
# ..                                                ...       ...
# 95  Mendonca Filho Um marco na politica .Veja sou ...  Negativo
# ...

# %%
dfBruno = pd.read_csv('./bruno')

# %%
array = [ 'Positivo',
        'Neutro',
        'Neutro',
        'Negativo',
        'Neutro',
        'Neutro',
        'Negativo',
        'Neutro',
        'Neutro',
        'Positivo',
        'Negativo',
        'Negativo',
        'Negativo',
        'Negativo',
        'Positivo',
        'Neutro',
        'Neutro',
        'Negativo',
        'Positivo',
        'Neutro',
        'Neutro',
        'Positivo',
        'Negativo',
        'Neutro',
        'Negativo',
        'Neutro',
        'Neutro',
        'Negativo',
        'Negativo',
        'Negativo',
        'Negativo',
        'Positivo',
        'Neutro',
        'Neutro',
        'Neutro',
        'Positivo',
        'Neutro',
        'Neutro',
        'Negativo',
        'Neutro',
        'Positivo',
        'Positivo',
        'Neutro',
        'Neutro',
        'Negativo',
        'Negativo',
        'Positivo',
        'Negativo',
        'Neutro',
        'Neutro',
        'Positivo'
]

# %%
dfBruno['Analise'] = array
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-58-23a9a5476f7c> in <module>
# ----> 1 dfBruno['Analise'] = array
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3038         else:
#    3039             # set column
# -> 3040             self._set_item(key, value)
#    3041
#    3042     def _setitem_slice(self, key: slice, value):
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3114         """
#    3115         self._ensure_valid_index(value)
# -> 3116         value = self._sanitize_column(key, value)
#    3117         NDFrame._set_item(self, key, value)
#    3118
#
# ~/.local/lib/python3.8/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    3759
#    3760             # turn me into an ndarray
# ...
