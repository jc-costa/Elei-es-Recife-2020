# %%
import tweepy
from wordcloud import WordCloud
import matplotlib.pyplot as plt 
from wordcloud import STOPWORDS
import pandas as pd
import sys

# %%
#credenciais da API do twitter
consumerKey = 'sYt53JHVZ5aKYrnKoy3hmL3ad'
consumerSecret = 'qMoCg6G7VneJjqNzkX3NMxblJD2aGZG3ylJnKINk0m2VvrXEgp'
accessToken = '1240872613876031488-StPoIim7kXuda00we1tDlv8damYEzU'
accessTokenSecret = 'axYYObMYwwkxbVj151we4GMgbcs0pk0jE3iOiHgGHBb9n'

# %%
#criação de um objeto de autentificação
authenticate = tweepy.OAuthHandler(consumerKey, consumerSecret)

#definindo o acesso ao token e ao token secret
authenticate.set_access_token(accessToken, accessTokenSecret)

#Criando a objeto API para passar as informações de autenticação
api = tweepy.API(authenticate, wait_on_rate_limit= True)

# %%
df_treino = pd.read_csv('./data/df_resultado_final_tweets_sem_stopwords')

# %%
df_treino
# Out:
#       Unnamed: 0   palavra_chave  \
# 0              0  Mendonça Filho
# 1              1  Mendonça Filho
# 2              2  Mendonça Filho
# 3              3  Mendonça Filho
# 4              4  Mendonça Filho
# ...          ...             ...
# 1995        1995  Marília Arraes
# 1996        1996  Marília Arraes
# 1997        1997  Marília Arraes
# 1998        1998  Marília Arraes
# 1999        1999  Marília Arraes
#
#                                                   tweet classificacao
# 0     pesquisa datafolha recife votos validos joao c...        Neutro
# 1     ibope recife votos validos joao campos psb 39 ...        Neutro
# 2     datafolha recife joao campos psb 29 2 marilia ...        Neutro
# 3     rejeicao delegada patricia podemos 42 coronel ...        Neutro
# 4     pessoa sai casa pra votar mendonca filho hein ...      Negativo
# ...                                                 ...           ...
# 1995  manuela poa pc b margarida juiz pt marilia cam...      Positivo
# 1996  recifenao vote marilia arraes joao camposeles ...      Positivo
# 1997  olha coisa linda futura prefeita marilia arrae...      Positivo
# 1998  nova pesquisa ipespe divulgada agora prefeitur...        Neutro
# 1999  nova pesquisa ipespe divulgada agora prefeitur...        Neutro
#
# [2000 rows x 4 columns]

# %%
df_treino.loc[df_treino ['palavra_chave'] == 'João Campos', :]
# Out:
#      Unnamed: 0 palavra_chave  \
# 500         500   João Campos
# 501         501   João Campos
# 502         502   João Campos
# 503         503   João Campos
# 504         504   João Campos
# ..          ...           ...
# 995         995   João Campos
# 996         996   João Campos
# 997         997   João Campos
# 998         998   João Campos
# 999         999   João Campos
#
#                                                  tweet classificacao
# 500  role aleatorio hj atravessar pistajoao campos ...      Negativo
# 501  pesquisa datafolha recife votos validos joao c...        Neutro
# 502  ibope recife votos validos joao campos psb 39 ...        Neutro
# 503  joao campos futuro prefeito recife recife 40 r...      Negativo
# 504  eleicoes2020 candidato prefeito recife joao ca...      Negativo
# ..                                                 ...           ...
# 995  nao acredito rio janeiro va votar eduardo paes...      Negativo
# 996  nao acredito rio janeiro va votar eduardo paes...      Negativo
# 997  nao acredito rio janeiro va votar eduardo paes...      Negativo
# 998  borges del patricia ficou votos bolsonaristas ...      Negativo
# 999  nao acredito rio janeiro va votar eduardo paes...      Negativo
#
# [500 rows x 4 columns]

# %%
Positivos = [] ; Negativos = []; Neutro = []

for i in range(0, df_treino.shape[0] ):
    if(df_treino['classificacao'][i] == 'Positivo'):
        Positivos.append(df_treino['tweet'][i])
    elif(df_treino['classificacao'][i] == 'Negativo'):
        Negativos.append(df_treino['tweet'][i])
    else:
        Neutro.append(df_treino['tweet'][i])

# %%
allPositivo = ' '.join(map(str, Positivos))
stop_words = ["ou", "e", "+", "https"] + list(STOPWORDS)
wordCloud1 = WordCloud(width = 500, background_color='white', stopwords = stop_words, height = 300, random_state = 21, max_font_size = 199).generate(allPositivo)

allNegativo = ' '.join(map(str, Negativos))
stop_words = ["ou", "e", "+", "https"] + list(STOPWORDS)
wordCloud2 = WordCloud(width = 500, background_color='white', stopwords = stop_words, height = 300, random_state = 21, max_font_size = 199).generate(allNegativo)

allNeutro = ' '.join(map(str, Neutro))
stop_words = ["ou", "e", "+", "https"] + list(STOPWORDS)
wordCloud3 = WordCloud(width = 500, background_color='white', stopwords = stop_words, height = 300, random_state = 21, max_font_size = 199).generate(allNeutro)

# %%
plt.imshow(wordCloud1, interpolation = "bilinear")
plt.axis('off')
#plt.savefig('C:/Users/jeffi/OneDrive/Área de Trabalho/Intro-multimidia/joaoPositivo.png')
plt.show()

plt.imshow(wordCloud2, interpolation = "bilinear")
plt.axis('off')
#plt.savefig('C:/Users/jeffi/OneDrive/Área de Trabalho/Intro-multimidia/joaoNegativo.png')
plt.show()

plt.imshow(wordCloud3, interpolation = "bilinear")
plt.axis('off')
#plt.savefig('C:/Users/jeffi/OneDrive/Área de Trabalho/Intro-multimidia/joaoNeutro.png')
plt.show()
